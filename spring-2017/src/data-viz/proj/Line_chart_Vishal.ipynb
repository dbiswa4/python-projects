# %%
# import modules
import pandas as pd

# Import the excel file and call it xls_file
xls_file = pd.ExcelFile('Updated_Data.xls')
xls_file
# View the excel file's sheet names
xls_file.sheet_names

df = xls_file.parse('Worksheet')
df
#df.Education.unique()
# Out:
#                         States             Education  Year2009  Year2010  \
# 0                     Nagaland     Upto 8th Standard        18         5
# 1                     Nagaland   9th and 10 standard         0         4
# 2                     NAgaland     Above standard 10        23         2
# 3                     Nagaland  Qualification Unnown        22        24
# 4    Andaman & Nicobar Islands     Upto 8th Standard        38        58
# 5    Andaman & Nicobar Islands   9th and 10 standard         0         0
# 6    Andaman & Nicobar Islands     Above standard 10       131       113
# 7    Andaman & Nicobar Islands  Qualification Unnown       102       114
# 8               Andhra Pradesh     Upto 8th Standard      9275      5220
# 9               Andhra Pradesh   9th and 10 standard     14617     23490
# 10              Andhra Pradesh     Above standard 10      9826      7849
# 11              Andhra Pradesh  Qualification Unnown      9882      8040
# ...

# %%
from numpy import genfromtxt
import matplotlib.pyplot as plt
plt.plot(df['Total'])
plt.xlabel ('x stuff')
plt.ylabel ('y stuff')
plt.title('my test result')
plt.show()

# %%
from bokeh.charts import Line, output_file, show

# prepare some data
Total = df.Total.tolist()
Year2009 = df.Year2009.tolist()
data = {"Accident": Total, "Accident2":Year2009}
#data = {"Accident": Total, "z": Year2009}


# create a new line chat with a title and axis labels
p = Line(data, title="simple line example", xlabel='x', ylabel='values', width=800, height=400)

# show the results
show(p)

# %%
ds =(df.set_index('States').T)
ds.Nagaland
# Out:
# States              Nagaland             Nagaland              Nagaland
# Education  Upto 8th Standard  9th and 10 standard  Qualification Unnown
# Year2009                  18                    0                    22
# Year2010                   5                    4                    24
# Year2011                   8                    0                    15
# Year2012                  11                    0                    13
# Year2013                  24                    0                    26
# Year2014                   0                  305                     0
# Year2015                  37                    0                    12
# Total                    103                  309                   112
